# %% [markdown]
# ## boston Air bnb dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

calendar = pd.read_csv('calendar.csv')
listings = pd.read_csv('listings.csv')
reviews = pd.read_csv("reviews.csv")
calendar.sample(5)
# Out:
#         listing_id        date available    price
# 846167     7869497  2017-05-20         t  $349.00
# 924643    13478868  2017-03-15         t   $42.00
# 906154     3309941  2017-01-24         f      NaN
# 178761     8442314  2016-12-02         f      NaN
# 909036     7741566  2017-02-25         t   $99.00

# %% [markdown]
# ### data exploration and Cleaning for caleandar dataset

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308890 entries, 0 to 1308889
# Data columns (total 4 columns):
# listing_id    1308890 non-null int64
# date          1308890 non-null object
# available     1308890 non-null object
# price         643037 non-null object
# dtypes: int64(1), object(3)
# memory usage: 39.9+ MB

# %%
calendar.price.isnull().sum()/calendar.shape[0]
# Out:
# 0.5087157820748879

# %% [markdown]
# - price have nearly 50.87% is missing data and wrong datatype
# - listing_id is wrong type as we wouldn't mathmitcal op. with it

# %%
calendar.describe()
# Out:
#          listing_id
# count  1.308890e+06
# mean   8.442118e+06
# std    4.500149e+06
# min    3.353000e+03
# 25%    4.679319e+06
# 50%    8.578710e+06
# 75%    1.279603e+07
# max    1.493346e+07

# %%
calendar.dropna(subset=['price'],axis=0,inplace=True)
calendar.price.astype(str)
calendar['date']= pd.to_datetime(calendar['date'])

# %%
wrangle_prices = lambda x : (x.replace('.00','').replace('$','').replace(',',''))
calendar.price=calendar.price.apply(wrangle_prices)
calendar['price'].head()
# Out:
# 365    65
# 366    65
# 367    65
# 368    75
# 369    75
# Name: price, dtype: object

# %%
calendar['price'].head()
# Out:
# 365    65
# 366    65
# 367    65
# 368    75
# 369    75
# Name: price, dtype: object

# %%
calendar['price'] = pd.to_numeric(calendar['price'])
calendar['listing_id'] =calendar['listing_id'].astype(str)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 643037 entries, 365 to 1308879
# Data columns (total 4 columns):
# listing_id    643037 non-null object
# date          643037 non-null datetime64[ns]
# available     643037 non-null object
# price         643037 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 24.5+ MB

# %%
calendar.describe()
# Out:
#                price
# count  643037.000000
# mean      198.438909
# std       180.142913
# min        11.000000
# 25%        85.000000
# 50%       150.000000
# 75%       255.000000
# max      7163.000000

# %% [markdown]
# ### data exploration and Cleaning for  listings Datasets

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
# id                                  3585 non-null int64
# listing_url                         3585 non-null object
# scrape_id                           3585 non-null int64
# last_scraped                        3585 non-null object
# name                                3585 non-null object
# summary                             3442 non-null object
# space                               2528 non-null object
# description                         3585 non-null object
# experiences_offered                 3585 non-null object
# neighborhood_overview               2170 non-null object
# notes                               1610 non-null object
# transit                             2295 non-null object
# access                              2096 non-null object
# interaction                         2031 non-null object
# house_rules                         2393 non-null object
# thumbnail_url                       2986 non-null object
# medium_url                          2986 non-null object
# picture_url                         3585 non-null object
# xl_picture_url                      2986 non-null object
# host_id                             3585 non-null int64
# host_url                            3585 non-null object
# host_name                           3585 non-null object
# host_since                          3585 non-null object
# host_location                       3574 non-null object
# host_about                          2276 non-null object
# host_response_time                  3114 non-null object
# host_response_rate                  3114 non-null object
# host_acceptance_rate                3114 non-null object
# host_is_superhost                   3585 non-null object
# host_thumbnail_url                  3585 non-null object
# host_picture_url                    3585 non-null object
# host_neighbourhood                  3246 non-null object
# host_listings_count                 3585 non-null int64
# host_total_listings_count           3585 non-null int64
# host_verifications                  3585 non-null object
# host_has_profile_pic                3585 non-null object
# host_identity_verified              3585 non-null object
# street                              3585 non-null object
# neighbourhood                       3042 non-null object
# neighbourhood_cleansed              3585 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                3583 non-null object
# state                               3585 non-null object
# zipcode                             3547 non-null object
# market                              3571 non-null object
# smart_location                      3585 non-null object
# country_code                        3585 non-null object
# country                             3585 non-null object
# latitude                            3585 non-null float64
# longitude                           3585 non-null float64
# is_location_exact                   3585 non-null object
# property_type                       3582 non-null object
# room_type                           3585 non-null object
# accommodates                        3585 non-null int64
# bathrooms                           3571 non-null float64
# bedrooms                            3575 non-null float64
# beds                                3576 non-null float64
# bed_type                            3585 non-null object
# amenities                           3585 non-null object
# square_feet                         56 non-null float64
# price                               3585 non-null object
# weekly_price                        892 non-null object
# monthly_price                       888 non-null object
# security_deposit                    1342 non-null object
# cleaning_fee                        2478 non-null object
# guests_included                     3585 non-null int64
# extra_people                        3585 non-null object
# minimum_nights                      3585 non-null int64
# maximum_nights                      3585 non-null int64
# calendar_updated                    3585 non-null object
# has_availability                    0 non-null float64
# availability_30                     3585 non-null int64
# availability_60                     3585 non-null int64
# availability_90                     3585 non-null int64
# availability_365                    3585 non-null int64
# calendar_last_scraped               3585 non-null object
# number_of_reviews                   3585 non-null int64
# first_review                        2829 non-null object
# last_review                         2829 non-null object
# review_scores_rating                2772 non-null float64
# review_scores_accuracy              2762 non-null float64
# review_scores_cleanliness           2767 non-null float64
# review_scores_checkin               2765 non-null float64
# review_scores_communication         2767 non-null float64
# review_scores_location              2763 non-null float64
# review_scores_value                 2764 non-null float64
# requires_license                    3585 non-null object
# license                             0 non-null float64
# jurisdiction_names                  0 non-null float64
# instant_bookable                    3585 non-null object
# cancellation_policy                 3585 non-null object
# require_guest_profile_picture       3585 non-null object
# require_guest_phone_verification    3585 non-null object
# calculated_host_listings_count      3585 non-null int64
# reviews_per_month                   2829 non-null float64
# dtypes: float64(18), int64(15), object(62)
# memory usage: 2.6+ MB

# %%
l=listings.isnull().sum()/listings.shape[0]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    print(l.sort_values(ascending=False,na_position='first')
)
# Out:
# neighbourhood_group_cleansed        1.000000
# jurisdiction_names                  1.000000
# license                             1.000000
# has_availability                    1.000000
# square_feet                         0.984379
# monthly_price                       0.752301
# weekly_price                        0.751185
# security_deposit                    0.625662
# notes                               0.550907
# interaction                         0.433473
# access                              0.415342
# neighborhood_overview               0.394700
# host_about                          0.365132
# transit                             0.359833
# house_rules                         0.332497
# cleaning_fee                        0.308787
# space                               0.294840
# review_scores_accuracy              0.229568
# review_scores_location              0.229289
# review_scores_value                 0.229010
# review_scores_checkin               0.228731
# review_scores_cleanliness           0.228173
# review_scores_communication         0.228173
# review_scores_rating                0.226778
# reviews_per_month                   0.210879
# first_review                        0.210879
# last_review                         0.210879
# thumbnail_url                       0.167085
# medium_url                          0.167085
# xl_picture_url                      0.167085
# neighbourhood                       0.151464
# host_response_time                  0.131381
# host_acceptance_rate                0.131381
# host_response_rate                  0.131381
# host_neighbourhood                  0.094561
# summary                             0.039888
# zipcode                             0.010600
# market                              0.003905
# bathrooms                           0.003905
# host_location                       0.003068
# bedrooms                            0.002789
# beds                                0.002510
# property_type                       0.000837
# city                                0.000558
# experiences_offered                 0.000000
# host_is_superhost                   0.000000
# host_thumbnail_url                  0.000000
# host_picture_url                    0.000000
# listing_url                         0.000000
# host_name                           0.000000
# scrape_id                           0.000000
# host_since                          0.000000
# description                         0.000000
# host_url                            0.000000
# host_id                             0.000000
# last_scraped                        0.000000
# picture_url                         0.000000
# name                                0.000000
# host_total_listings_count           0.000000
# host_listings_count                 0.000000
# country                             0.000000
# host_verifications                  0.000000
# availability_365                    0.000000
# minimum_nights                      0.000000
# maximum_nights                      0.000000
# calendar_updated                    0.000000
# availability_30                     0.000000
# availability_60                     0.000000
# availability_90                     0.000000
# calendar_last_scraped               0.000000
# host_has_profile_pic                0.000000
# number_of_reviews                   0.000000
# requires_license                    0.000000
# instant_bookable                    0.000000
# cancellation_policy                 0.000000
# require_guest_profile_picture       0.000000
# require_guest_phone_verification    0.000000
# extra_people                        0.000000
# guests_included                     0.000000
# price                               0.000000
# amenities                           0.000000
# bed_type                            0.000000
# accommodates                        0.000000
# room_type                           0.000000
# is_location_exact                   0.000000
# longitude                           0.000000
# latitude                            0.000000
# calculated_host_listings_count      0.000000
# country_code                        0.000000
# smart_location                      0.000000
# state                               0.000000
# neighbourhood_cleansed              0.000000
# street                              0.000000
# host_identity_verified              0.000000
# id                                  0.000000
# dtype: float64

# %% [markdown]
# -  analsyes depend on prices and costs of units so I'm between droping the missing prices raws  or imputing him as unfortunitly can't predict as main featuers to predict like square_feet and etc have high missing data so will focse more in reviwes

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.585000e+03  3.585000e+03  3.585000e+03          3585.000000
# mean   8.440875e+06  2.016091e+13  2.492311e+07            58.902371
# std    4.500787e+06  8.516813e-01  2.292781e+07           171.119663
# min    3.353000e+03  2.016091e+13  4.240000e+03             0.000000
# 25%    4.679319e+06  2.016091e+13  6.103425e+06             1.000000
# 50%    8.577620e+06  2.016091e+13  1.928100e+07             2.000000
# 75%    1.278953e+07  2.016091e+13  3.622147e+07             7.000000
# max    1.493346e+07  2.016091e+13  9.385411e+07           749.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3585.000000                           0.0  3585.000000
# mean                   58.902371                           NaN    42.340032
# std                   171.119663                           NaN     0.024403
# min                     0.000000                           NaN    42.235942
# 25%                     1.000000                           NaN    42.329995
# 50%                     2.000000                           NaN    42.345201
# 75%                     7.000000                           NaN    42.354685
# max                   749.000000                           NaN    42.389982
#
#          longitude  accommodates    bathrooms  ...  review_scores_accuracy  \
# count  3585.000000   3585.000000  3571.000000  ...             2762.000000
# mean    -71.084818      3.041283     1.221647  ...                9.431571
# std       0.031565      1.778929     0.501487  ...                0.931863
# min     -71.171789      1.000000     0.000000  ...                2.000000
# 25%     -71.105083      2.000000     1.000000  ...                9.000000
# 50%     -71.078429      2.000000     1.000000  ...               10.000000
# 75%     -71.062155      4.000000     1.000000  ...               10.000000
# max     -71.000100     16.000000     6.000000  ...               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                2767.000000            2765.000000
# mean                    9.258041               9.646293
# std                     1.168977               0.762753
# min                     2.000000               2.000000
# 25%                     9.000000               9.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  2767.000000             2763.000000
# mean                      9.646549                9.414043
# std                       0.735507                0.903436
# min                       4.000000                2.000000
# 25%                       9.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  license  jurisdiction_names  \
# count          2764.000000      0.0                 0.0
# mean              9.168234      NaN                 NaN
# std               1.011116      NaN                 NaN
# min               2.000000      NaN                 NaN
# 25%               9.000000      NaN                 NaN
# 50%               9.000000      NaN                 NaN
# 75%              10.000000      NaN                 NaN
# max              10.000000      NaN                 NaN
#
#        calculated_host_listings_count  reviews_per_month
# count                     3585.000000        2829.000000
# mean                        12.733891           1.970908
# std                         29.415076           2.120561
# min                          1.000000           0.010000
# 25%                          1.000000           0.480000
# 50%                          2.000000           1.170000
# 75%                          6.000000           2.720000
# max                        136.000000          19.150000
#
# [8 rows x 33 columns]

# %%
listings[listings['host_total_listings_count']==749]
# Out:
#             id                            listing_url       scrape_id  \
# 428   12089399  https://www.airbnb.com/rooms/12089399  20160906204935
# 442   12102482  https://www.airbnb.com/rooms/12102482  20160906204935
# 443    6744795   https://www.airbnb.com/rooms/6744795  20160906204935
# 455   10153739  https://www.airbnb.com/rooms/10153739  20160906204935
# 468    8184662   https://www.airbnb.com/rooms/8184662  20160906204935
# ...        ...                                    ...             ...
# 3074  10052824  https://www.airbnb.com/rooms/10052824  20160906204935
# 3075  10052622  https://www.airbnb.com/rooms/10052622  20160906204935
# 3078  10052920  https://www.airbnb.com/rooms/10052920  20160906204935
# 3081  10051623  https://www.airbnb.com/rooms/10051623  20160906204935
# 3084  10052445  https://www.airbnb.com/rooms/10052445  20160906204935
#
#      last_scraped                                 name  \
# 428    2016-09-07    Furnished Longwood 1BR Apartment.
# 442    2016-09-07    Furnished Longwood 1BR Apartment.
# 443    2016-09-07     Furnished Longwood 1BR Apartment
# 455    2016-09-07     Lux Furnished 1BR Boston MA Apt.
# 468    2016-09-07    Furnished Longwood 1BR Apartment.
# ...           ...                                  ...
# 3074   2016-09-07        Lux. 3 BR Apt Near Fort Point
# 3075   2016-09-07  Lux. 3 BR Apt. - Financial District
# 3078   2016-09-07     Lux. 3BR by the Seaport & Harbor
# 3081   2016-09-07  Lux 2BR In Seaport Square on Harbor
# 3084   2016-09-07  Stunning 3 BR Lux Apt on the Harbor
#
#                                                 summary  \
# 428   Located on the Green Line at the Longwood Medi...
# 442   Located on the Green Line at the Longwood Medi...
# 443   This beautiful apartment is complete with a fu...
# 455   This beautiful apartment is complete with a fu...
# 468   This beautiful apartment is complete with a fu...
# ...                                                 ...
# 3074  Luxury high-rise apt. with unparalleled amenit...
# 3075  Luxury high-rise apt. with unparalleled amenit...
# 3078  Luxury high-rise apt. with unparalleled amenit...
# 3081  Luxury high-rise apt. with unparalleled amenit...
# 3084  Luxury high-rise apt. with unparalleled amenit...
#
#                                                   space  \
# 428   1 Bed, 1 Bath, Sleeps 3 Longwood Medical Area ...
# 442   1 Bed, 1 Bath, Sleeps 3 Longwood Medical Area ...
# 443                                                 NaN
# 455   1 Bed, 1 Bath, Sleeps 3 Longwood Medical Area ...
# 468                              B(PHONE NUMBER HIDDEN)
# ...                                                 ...
# 3074  Our luxury high-rise apt. is conveniently loca...
# 3075  Our luxury high-rise apt. is conveniently loca...
# 3078  Our luxury high-rise apt. is conveniently loca...
# 3081  Our luxury high-rise apt. is conveniently loca...
# 3084  Our luxury high-rise apt. is conveniently loca...
#
#                                             description experiences_offered  \
# 428   Located on the Green Line at the Longwood Medi...                none
# 442   Located on the Green Line at the Longwood Medi...                none
# 443   This beautiful apartment is complete with a fu...                none
# 455   This beautiful apartment is complete with a fu...                none
# 468   This beautiful apartment is complete with a fu...                none
# ...                                                 ...                 ...
# 3074  Luxury high-rise apt. with unparalleled amenit...                none
# 3075  Luxury high-rise apt. with unparalleled amenit...                none
# 3078  Luxury high-rise apt. with unparalleled amenit...                none
# 3081  Luxury high-rise apt. with unparalleled amenit...                none
# 3084  Luxury high-rise apt. with unparalleled amenit...                none
#
#                                   neighborhood_overview  ...  \
# 428   Major Attractions: •Restaurants – Il Mondo Piz...  ...
# 442   Major Attractions: •Restaurants – Il Mondo Piz...  ...
# 443                                                 NaN  ...
# 455   Major Attractions: •Restaurants – Il Mondo Piz...  ...
# 468   This property is located on the Green Line at ...  ...
# ...                                                 ...  ...
# 3074                                                NaN  ...
# 3075                                                NaN  ...
# 3078                                                NaN  ...
# 3081                                                NaN  ...
# 3084                                                NaN  ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 428                  NaN                f     NaN                NaN
# 442                  NaN                f     NaN                NaN
# 443                  NaN                f     NaN                NaN
# 455                  NaN                f     NaN                NaN
# 468                  2.0                f     NaN                NaN
# ...                  ...              ...     ...                ...
# 3074                10.0                f     NaN                NaN
# 3075                 NaN                f     NaN                NaN
# 3078                 NaN                f     NaN                NaN
# 3081                 NaN                f     NaN                NaN
# 3084                 NaN                f     NaN                NaN
#
#      instant_bookable cancellation_policy require_guest_profile_picture  \
# 428                 f              strict                             f
# 442                 f              strict                             f
# 443                 f              strict                             f
# 455                 f              strict                             f
# 468                 f              strict                             f
# ...               ...                 ...                           ...
# 3074                f              strict                             f
# 3075                f              strict                             f
# 3078                f              strict                             f
# 3081                f              strict                             f
# 3084                f              strict                             f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 428                                 f                            136
# 442                                 f                            136
# 443                                 f                            136
# 455                                 f                            136
# 468                                 f                            136
# ...                               ...                            ...
# 3074                                f                            136
# 3075                                f                            136
# 3078                                f                            136
# 3081                                f                            136
# 3084                                f                            136
#
#       reviews_per_month
# 428                 NaN
# 442                 NaN
# 443                 NaN
# 455                 NaN
# 468                0.22
# ...                 ...
# 3074               0.21
# 3075                NaN
# 3078                NaN
# 3081                NaN
# 3084                NaN
#
# [136 rows x 95 columns]

# %%
listings.dropna(subset=['review_scores_rating','price','review_scores_value'],axis=0,inplace=True)

# %%
listings.drop(['jurisdiction_names','license','has_availability','square_feet','neighbourhood_group_cleansed'],axis=1,inplace=True )

# %%
l=listings.isnull().sum()/listings.shape[0]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(l.sort_values(ascending=False,na_position='first')
)
# Out:
# monthly_price                       0.714803
# weekly_price                        0.703945
# security_deposit                    0.595367
# notes                               0.498009
# interaction                         0.373507
# access                              0.348172
# neighborhood_overview               0.344915
# transit                             0.312342
# host_about                          0.311980
# cleaning_fee                        0.286283
# house_rules                         0.266377
# space                               0.242852
# medium_url                          0.171915
# xl_picture_url                      0.171915
# thumbnail_url                       0.171915
# neighbourhood                       0.145856
# host_neighbourhood                  0.088310
# host_acceptance_rate                0.078538
# host_response_time                  0.078538
# host_response_rate                  0.078538
# summary                             0.045603
# zipcode                             0.009048
# bathrooms                           0.004343
# host_location                       0.003257
# bedrooms                            0.002533
# beds                                0.002172
# market                              0.002172
# review_scores_accuracy              0.001448
# property_type                       0.000724
# review_scores_location              0.000724
# city                                0.000724
# review_scores_cleanliness           0.000362
# review_scores_checkin               0.000362
# review_scores_communication         0.000362
# host_thumbnail_url                  0.000000
# host_picture_url                    0.000000
# host_is_superhost                   0.000000
# host_listings_count                 0.000000
# host_total_listings_count           0.000000
# reviews_per_month                   0.000000
# host_url                            0.000000
# host_since                          0.000000
# host_name                           0.000000
# host_has_profile_pic                0.000000
# host_id                             0.000000
# picture_url                         0.000000
# experiences_offered                 0.000000
# description                         0.000000
# name                                0.000000
# last_scraped                        0.000000
# scrape_id                           0.000000
# listing_url                         0.000000
# host_verifications                  0.000000
# smart_location                      0.000000
# host_identity_verified              0.000000
# street                              0.000000
# availability_30                     0.000000
# availability_60                     0.000000
# availability_90                     0.000000
# availability_365                    0.000000
# calendar_last_scraped               0.000000
# number_of_reviews                   0.000000
# first_review                        0.000000
# last_review                         0.000000
# review_scores_rating                0.000000
# review_scores_value                 0.000000
# requires_license                    0.000000
# instant_bookable                    0.000000
# cancellation_policy                 0.000000
# require_guest_profile_picture       0.000000
# require_guest_phone_verification    0.000000
# calendar_updated                    0.000000
# maximum_nights                      0.000000
# minimum_nights                      0.000000
# longitude                           0.000000
# neighbourhood_cleansed              0.000000
# state                               0.000000
# calculated_host_listings_count      0.000000
# country_code                        0.000000
# country                             0.000000
# latitude                            0.000000
# is_location_exact                   0.000000
# extra_people                        0.000000
# room_type                           0.000000
# accommodates                        0.000000
# bed_type                            0.000000
# amenities                           0.000000
# price                               0.000000
# guests_included                     0.000000
# id                                  0.000000
# dtype: float64

# %%
listings[listings['host_total_listings_count']==749]
# Out:
#             id                            listing_url       scrape_id  \
# 468    8184662   https://www.airbnb.com/rooms/8184662  20160906204935
# 488    7868931   https://www.airbnb.com/rooms/7868931  20160906204935
# 556   12303347  https://www.airbnb.com/rooms/12303347  20160906204935
# 572   10611728  https://www.airbnb.com/rooms/10611728  20160906204935
# 575   12302222  https://www.airbnb.com/rooms/12302222  20160906204935
# 579   12383204  https://www.airbnb.com/rooms/12383204  20160906204935
# 589   10116726  https://www.airbnb.com/rooms/10116726  20160906204935
# 599   10116429  https://www.airbnb.com/rooms/10116429  20160906204935
# 611   10116601  https://www.airbnb.com/rooms/10116601  20160906204935
# 624   10117329  https://www.airbnb.com/rooms/10117329  20160906204935
# 1301   9993602   https://www.airbnb.com/rooms/9993602  20160906204935
# 1339   9991857   https://www.airbnb.com/rooms/9991857  20160906204935
# 1418   9920084   https://www.airbnb.com/rooms/9920084  20160906204935
# 1449   9918713   https://www.airbnb.com/rooms/9918713  20160906204935
# 1463   5870309   https://www.airbnb.com/rooms/5870309  20160906204935
# 1797   7596262   https://www.airbnb.com/rooms/7596262  20160906204935
# 1799  12088322  https://www.airbnb.com/rooms/12088322  20160906204935
# 1815  10051842  https://www.airbnb.com/rooms/10051842  20160906204935
# 1822   6015995   https://www.airbnb.com/rooms/6015995  20160906204935
# 2070  12383703  https://www.airbnb.com/rooms/12383703  20160906204935
# 2108  10117803  https://www.airbnb.com/rooms/10117803  20160906204935
# 2114   9922595   https://www.airbnb.com/rooms/9922595  20160906204935
# 2117  11983535  https://www.airbnb.com/rooms/11983535  20160906204935
# 2249   6027467   https://www.airbnb.com/rooms/6027467  20160906204935
# 2270   6951829   https://www.airbnb.com/rooms/6951829  20160906204935
# 2291   6844012   https://www.airbnb.com/rooms/6844012  20160906204935
# 2301   8165898   https://www.airbnb.com/rooms/8165898  20160906204935
# 2317   7869497   https://www.airbnb.com/rooms/7869497  20160906204935
# 2319   6790961   https://www.airbnb.com/rooms/6790961  20160906204935
# 2328  10149314  https://www.airbnb.com/rooms/10149314  20160906204935
# 2335  11985521  https://www.airbnb.com/rooms/11985521  20160906204935
# 2337   8336347   https://www.airbnb.com/rooms/8336347  20160906204935
# 2355  10036037  https://www.airbnb.com/rooms/10036037  20160906204935
# 2360  10033715  https://www.airbnb.com/rooms/10033715  20160906204935
# 2361   6015021   https://www.airbnb.com/rooms/6015021  20160906204935
# 2364  11987762  https://www.airbnb.com/rooms/11987762  20160906204935
# 2368  12246137  https://www.airbnb.com/rooms/12246137  20160906204935
# 2396   7508865   https://www.airbnb.com/rooms/7508865  20160906204935
# 2403  10228228  https://www.airbnb.com/rooms/10228228  20160906204935
# 2414   8163273   https://www.airbnb.com/rooms/8163273  20160906204935
# 2418   8097453   https://www.airbnb.com/rooms/8097453  20160906204935
# 2421   8146576   https://www.airbnb.com/rooms/8146576  20160906204935
# 2431   7573274   https://www.airbnb.com/rooms/7573274  20160906204935
# 2449   8325544   https://www.airbnb.com/rooms/8325544  20160906204935
# 2461   5834413   https://www.airbnb.com/rooms/5834413  20160906204935
# 2467   6793913   https://www.airbnb.com/rooms/6793913  20160906204935
# 3048  13221129  https://www.airbnb.com/rooms/13221129  20160906204935
# 3049  10051357  https://www.airbnb.com/rooms/10051357  20160906204935
# 3050  10050351  https://www.airbnb.com/rooms/10050351  20160906204935
# 3066  10054046  https://www.airbnb.com/rooms/10054046  20160906204935
# 3074  10052824  https://www.airbnb.com/rooms/10052824  20160906204935
#
#      last_scraped                                 name  \
# 468    2016-09-07    Furnished Longwood 1BR Apartment.
# 488    2016-09-07    Furnished Longwood 1-BR Apartment
# 556    2016-09-07      Luxury Furnished 1BR Boston Apt
# 572    2016-09-07    LUX 1 Bedroom Downtown Boston Apt
# 575    2016-09-07                Luxury 2BR Boston Apt
# 579    2016-09-07  Dowtown Boston 2BR Apt.-Opera House
# 589    2016-09-07  Dowtown Boston 1BR Apt-Logan Airprt
# 599    2016-09-07  Dowtown Boston 1BR Apt.+Indoor Pool
# 611    2016-09-07   Dowtown Boston 1BR Apt+Indoor Pool
# 624    2016-09-07    LUX Boston 2BR Apt. Logan Airport
# 1301   2016-09-07                 Lux 1BR Back Bay Apt
# 1339   2016-09-07  2BR Lux BackBay Apt. by Fenway Park
# 1418   2016-09-07  Lux 2BR Back Bay Apt Near South End
# 1449   2016-09-07           Lux 2BR Back Bay Apartment
# 1463   2016-09-07     Lux 2BR Apt By Prudential Center
# 1797   2016-09-07   Furnished Luxury 1BR West End Apt.
# 1799   2016-09-07     Furnished Luxury 2BR at West End
# 1815   2016-09-07             Luxury West End 2BR Apt.
# 1822   2016-09-07   1BR West End Apt. near Restaurants
# 2070   2016-09-07   Dowtown Boston 2BR Apt-Opera House
# 2108   2016-09-07  Dowtown Boston 2BR Apt+ Indoor Pool
# 2114   2016-09-07  Dowtown Boston 1BR Apt.-Opera House
# 2117   2016-09-07  DOWNTOWN BOSTON 2BR APT-OPERA HOUSE
# 2249   2016-09-07    Luxury 1BR in Boston/ Fenway Area
# 2270   2016-09-07  Lux Furnished 2BR in Boston/ Fenway
# 2291   2016-09-07        Luxury 2BR in Boston & Fenway
# 2301   2016-09-07     Boston Fenway furnished 2br apt.
# 2317   2016-09-07                New Lux 1BR at Fenway
# 2319   2016-09-07   Luxury 2BR in Boston/ Fenway Area.
# 2328   2016-09-07        Lux Furnished 1BR Boston Apt.
# 2335   2016-09-07  Lux Furnished 1BR Boston Apt.+Pool!
# 2337   2016-09-07     Boston Fenway 2BR Furnished Apt.
# 2355   2016-09-07   New Luxury 2BR-Apartment at Fenway
# 2360   2016-09-07   New Luxury 2BR Apartment at Fenway
# 2361   2016-09-07   Lux Fully Furnished 1BR Boston Apt
# 2364   2016-09-07  Lux Furnished Boston 2BR Apt+ Pool!
# 2368   2016-09-07               Luxury 1BR Boston Apt.
# 2396   2016-09-07        Luxury 1BR Apt in Fenway Area
# 2403   2016-09-07        Lux 1BR Furnished Boston Apt.
# 2414   2016-09-07        2br Lux Apt. in Boston Fenway
# 2418   2016-09-07      Luxury 1BR Boston Apt in Fenway
# 2421   2016-09-07  Luxurious 2Br apt. in Boston Fenway
# 2431   2016-09-07  Luxury 2BR/2BA Apt. + Outdoor Pool!
# 2449   2016-09-07        2br Lux Apt. in Boston Fenway
# 2461   2016-09-07    Luxury 2BR in Boston/ Fenway Area
# 2467   2016-09-07   Luxury 2BR in Boston & Fenway Area
# 3048   2016-09-07         Boston 1BR Lux Furnished Apt
# 3049   2016-09-07        Gorgeous 2BR On Boston Harbor
# 3050   2016-09-07       Gorgeous 1BR In Seaport Square
# 3066   2016-09-07  Stunning 1BR HighRise Apt by Harbor
# 3074   2016-09-07        Lux. 3 BR Apt Near Fort Point
#
#                                                 summary  \
# 468   This beautiful apartment is complete with a fu...
# 488   Located on the Green Line at the Longwood Medi...
# 556   At the intersection of the charming Leather Di...
# 572   Our stunning apt. features oversized windows, ...
# 575   At the intersection of the charming Leather Di...
# 579   Our beautifully furnished apartment is complet...
# 589   This beautifully furnished apartment is comple...
# 599   This beautifully furnished apartment is comple...
# 611   This beautifully furnished apartment is comple...
# 624   This beautifully furnished apartment is comple...
# 1301  This beautiful apartment is complete with a fu...
# 1339  This beautiful apartment is complete with a fu...
# 1418  This beautiful apartment is complete with a fu...
# 1449  This beautiful apartment is complete with a fu...
# 1463  This luxury apartment community in Back Bay an...
# 1797  Come enjoy our beautiful apartment home - with...
# 1799  With so much to do on the premises, this apart...
# 1815  This beautifully furnished apartment is comple...
# 1822  Residents can enjoy beautiful apartment homes ...
# 2070  Our beautifully furnished apartment is complet...
# 2108  Our beautifully furnished apartment is complet...
# 2114  Our beautifully furnished apartment is complet...
# 2117  Our beautifully furnished apartment is complet...
# 2249  This 1 bedroom, apartment is centrally located...
# 2270  This beautifully furnished apartment is comple...
# 2291  This 2 bedroom, apartment is centrally located...
# 2301  This beautiful apartment is complete with a fu...
# 2317  This furnished apartment is complete with a fu...
# 2319  This 2 bedroom, apartment is centrally located...
# 2328  These newly constructed, luxury apartments all...
# 2335  In the heart of Fenway with endless entertainm...
# 2337  This apartment has a fully equipped kitchen, s...
# 2355  This furnished apartment is complete with a fu...
# 2360  This furnished apartment is complete with a fu...
# 2361  Residents will enjoy the great on-site ameniti...
# 2364  In the heart of Fenway with endless entertainm...
# 2368  Based in the heart of the Fenway neighborhood,...
# 2396  This beautifully furnished apartment is comple...
# 2403  This apartment is complete with a fully equipp...
# 2414  This apartment is complete with a fully equipp...
# 2418  This apartment is complete with a fully equipp...
# 2421  This apt. is complete with a fully furnished k...
# 2431  In the heart of Fenway with endless entertainm...
# 2449  This apartment has a fully equipped kitchen, s...
# 2461  This 2 bedroom, apartment is centrally located...
# 2467  This 2 bedroom, apartment is centrally located...
# 3048  This Apt offers residents a fully equipped kit...
# 3049  Luxury high-rise apt. with unparalleled amenit...
# 3050  Luxury high-rise apt. with unparalleled amenit...
# 3066  Luxury high-rise apt. with unparalleled amenit...
# 3074  Luxury high-rise apt. with unparalleled amenit...
#
#                                                   space  \
# 468                              B(PHONE NUMBER HIDDEN)
# 488   1 Bed, 1 Bath, Sleeps 3 Longwood Medical Area ...
# 556   1 Bed, 1 Bath, Sleeps 3 A distinctive presence...
# 572   1 Bed, 1 Bath, Sleeps 3 A distinctive presence...
# 575   1 Bed, 1 Bath, Sleeps 3 A distinctive presence...
# 579   2 Bed, 2 Bath, Sleeps 5 This apartment is perf...
# 589   1 Bed, 1 Bath, Sleeps 3 This apartment is perf...
# 599   1 Bed, 1 Bath, Sleeps 3 This apartment is perf...
# 611   1 Bed, 1 Bath, Sleeps 3 This apartment is perf...
# 624   1 Bed, 1 Bath, Sleeps 3 This apartment is perf...
# 1301                                           B196/306
# 1339  This building's historic 19th century façade, ...
# 1418  This building's historic 19th century façade, ...
# 1449  This building's historic 19th century façade, ...
# 1463  This building's historic 19th century façade, ...
# 1797  •24 hour concierge service •Tennis court •Bask...
# 1799  2 Bed, 2 Bath, Sleeps 5 The building is locate...
# 1815                                           B659/703
# 1822  •24 hour concierge service •Tennis court •Bask...
# 2070  2 Bed, 2 Bath, Sleeps 5 This apartment is perf...
# 2108  1 Bed, 1 Bath, Sleeps 3 This apartment is perf...
# 2114  1 Bed, 1 Bath, Sleeps 3 This apartment is perf...
# 2117  2 Bed, 2 Bath, Sleeps 5 This apartment is perf...
# 2249                                                NaN
# 2270                                                NaN
# 2291                                              HB932
# 2301                                                NaN
# 2317                                              B1008
# 2319                                                NaN
# 2328  1 Bed, 1 Bath, Sleeps 3 Both elegant and moder...
# 2335  1 Bed, 1 Bath, Sleeps 3 Both elegant and moder...
# 2337                             B(PHONE NUMBER HIDDEN)
# 2355                                               B994
# 2360                                                NaN
# 2361                                                NaN
# 2364                                                NaN
# 2368  1 Bed, 1 Bath, Sleeps 3 These newly constructe...
# 2396                                               B849
# 2403                                                NaN
# 2414                                                NaN
# 2418  This community offers spectacular on-site amen...
# 2421                                                NaN
# 2431  2 Bed, 2 Bath, Sleeps 5 Both elegant and moder...
# 2449  2 Bed, 2 Bath, Sleeps 5 These newly constructe...
# 2461                                                NaN
# 2467                                                NaN
# 3048  1 Bed, 1 Bath, Sleeps 3 When Boston Harbor mee...
# 3049  Our luxury high-rise apt. is conveniently loca...
# 3050  Our luxury high-rise apt. is conveniently loca...
# 3066  Our luxury high-rise apt. is conveniently loca...
# 3074  Our luxury high-rise apt. is conveniently loca...
#
#                                             description experiences_offered  \
# 468   This beautiful apartment is complete with a fu...                none
# 488   Located on the Green Line at the Longwood Medi...                none
# 556   At the intersection of the charming Leather Di...                none
# 572   Our stunning apt. features oversized windows, ...                none
# 575   At the intersection of the charming Leather Di...                none
# 579   Our beautifully furnished apartment is complet...                none
# 589   This beautifully furnished apartment is comple...                none
# 599   This beautifully furnished apartment is comple...                none
# 611   This beautifully furnished apartment is comple...                none
# 624   This beautifully furnished apartment is comple...                none
# 1301  This beautiful apartment is complete with a fu...                none
# 1339  This beautiful apartment is complete with a fu...                none
# 1418  This beautiful apartment is complete with a fu...                none
# 1449  This beautiful apartment is complete with a fu...                none
# 1463  This luxury apartment community in Back Bay an...                none
# 1797  Come enjoy our beautiful apartment home - with...                none
# 1799  With so much to do on the premises, this apart...                none
# 1815  This beautifully furnished apartment is comple...                none
# 1822  Residents can enjoy beautiful apartment homes ...                none
# 2070  Our beautifully furnished apartment is complet...                none
# 2108  Our beautifully furnished apartment is complet...                none
# 2114  Our beautifully furnished apartment is complet...                none
# 2117  Our beautifully furnished apartment is complet...                none
# 2249  This 1 bedroom, apartment is centrally located...                none
# 2270  This beautifully furnished apartment is comple...                none
# 2291  This 2 bedroom, apartment is centrally located...                none
# 2301  This beautiful apartment is complete with a fu...                none
# 2317  This furnished apartment is complete with a fu...                none
# 2319  This 2 bedroom, apartment is centrally located...                none
# 2328  These newly constructed, luxury apartments all...                none
# 2335  In the heart of Fenway with endless entertainm...                none
# 2337  This apartment has a fully equipped kitchen, s...                none
# 2355  This furnished apartment is complete with a fu...                none
# 2360  This furnished apartment is complete with a fu...                none
# 2361  Residents will enjoy the great on-site ameniti...                none
# 2364  In the heart of Fenway with endless entertainm...                none
# 2368  Based in the heart of the Fenway neighborhood,...                none
# 2396  This beautifully furnished apartment is comple...                none
# 2403  This apartment is complete with a fully equipp...                none
# 2414  This apartment is complete with a fully equipp...                none
# 2418  This apartment is complete with a fully equipp...                none
# 2421  This apt. is complete with a fully furnished k...                none
# 2431  In the heart of Fenway with endless entertainm...                none
# 2449  This apartment has a fully equipped kitchen, s...                none
# 2461  This 2 bedroom, apartment is centrally located...                none
# 2467  This 2 bedroom, apartment is centrally located...                none
# 3048  This Apt offers residents a fully equipped kit...                none
# 3049  Luxury high-rise apt. with unparalleled amenit...                none
# 3050  Luxury high-rise apt. with unparalleled amenit...                none
# 3066  Luxury high-rise apt. with unparalleled amenit...                none
# 3074  Luxury high-rise apt. with unparalleled amenit...                none
#
#                                   neighborhood_overview  ...  \
# 468   This property is located on the Green Line at ...  ...
# 488   Major Attractions: •Restaurants – Il Mondo Piz...  ...
# 556   Major Attractions: •Rose Kennedy Greenway – pu...  ...
# 572   Major Attractions: •Rose Kennedy Greenway – pu...  ...
# 575   Major Attractions: •Rose Kennedy Greenway – pu...  ...
# 579   Major Attractions: •Restaurants – The Q Restau...  ...
# 589   Major Attractions: •Restaurants – The Q Restau...  ...
# 599   Major Attractions: •Restaurants – The Q Restau...  ...
# 611   Major Attractions: •Restaurants – The Q Restau...  ...
# 624   Major Attractions: •Restaurants – The Q Restau...  ...
# 1301  This apartment is located at the crossroads of...  ...
# 1339  This apartment is located at the crossroads of...  ...
# 1418  This apartment is located at the crossroads of...  ...
# 1449  This apartment is located at the crossroads of...  ...
# 1463  This apartment is located at the crossroads of...  ...
# 1797                                                NaN  ...
# 1799  Major Attractions: •Restaurants - Dean’s List ...  ...
# 1815  Residents will find themselves in the center o...  ...
# 1822                                                NaN  ...
# 2070  Major Attractions: •Restaurants – The Q Restau...  ...
# 2108  Major Attractions: •Restaurants – The Q Restau...  ...
# 2114  Major Attractions: •Restaurants – The Q Restau...  ...
# 2117  Major Attractions: •Restaurants – The Q Restau...  ...
# 2249  Residents will find themselves right in the he...  ...
# 2270  This Fenway apartment is centrally located, cl...  ...
# 2291                                                NaN  ...
# 2301  Residents will find themselves right in the he...  ...
# 2317                                                NaN  ...
# 2319                                                NaN  ...
# 2328  Major Attractions: •Restaurants - High-end Ame...  ...
# 2335  Major Attractions: •Restaurants - High-end Ame...  ...
# 2337  Residents will find themselves right in the he...  ...
# 2355                                                NaN  ...
# 2360                                                NaN  ...
# 2361                                                NaN  ...
# 2364                                                NaN  ...
# 2368  Major Attractions: •Restaurants - High-end Ame...  ...
# 2396  This apartment is centrally located in Fenway ...  ...
# 2403  Residents will find themselves right in the he...  ...
# 2414  Residents will find themselves right in the he...  ...
# 2418  Residents will find themselves right in the he...  ...
# 2421  Residents will find themselves right in the he...  ...
# 2431  Major Attractions: •Restaurants - High-end Ame...  ...
# 2449  Major Attractions: •Restaurants - High-end Ame...  ...
# 2461                                                NaN  ...
# 2467                                                NaN  ...
# 3048  This apartment puts The Seaport and the City r...  ...
# 3049                                                NaN  ...
# 3050                                                NaN  ...
# 3066                                                NaN  ...
# 3074                                                NaN  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 468                          4.0                   10.0                 2.0
# 488                         10.0                   10.0                 7.0
# 556                         10.0                   10.0                 8.0
# 572                         10.0                   10.0                10.0
# 575                         10.0                   10.0                 8.0
# 579                         10.0                    8.0                 8.0
# 589                          8.0                    8.0                 8.0
# 599                          8.0                   10.0                10.0
# 611                         10.0                   10.0                10.0
# 624                         10.0                   10.0                10.0
# 1301                        10.0                   10.0                 6.0
# 1339                        10.0                   10.0                10.0
# 1418                         9.0                   10.0                 7.0
# 1449                         6.0                   10.0                 8.0
# 1463                         8.0                    8.0                 8.0
# 1797                         8.0                    9.0                 9.0
# 1799                        10.0                   10.0                 6.0
# 1815                         8.0                   10.0                 6.0
# 1822                         8.0                    9.0                 8.0
# 2070                        10.0                   10.0                 8.0
# 2108                         7.0                    9.0                 9.0
# 2114                        10.0                   10.0                10.0
# 2117                        10.0                   10.0                10.0
# 2249                         9.0                   10.0                 9.0
# 2270                        10.0                   10.0                10.0
# 2291                        10.0                   10.0                10.0
# 2301                         7.0                   10.0                 9.0
# 2317                         6.0                    8.0                 6.0
# 2319                        10.0                   10.0                10.0
# 2328                        10.0                    8.0                 8.0
# 2335                        10.0                   10.0                10.0
# 2337                        10.0                   10.0                10.0
# 2355                         4.0                    2.0                 4.0
# 2360                        10.0                   10.0                10.0
# 2361                         7.0                   10.0                 8.0
# 2364                         4.0                    8.0                 2.0
# 2368                        10.0                   10.0                10.0
# 2396                         9.0                    9.0                 8.0
# 2403                         8.0                   10.0                 6.0
# 2414                        10.0                   10.0                 4.0
# 2418                        10.0                    2.0                 2.0
# 2421                        10.0                   10.0                10.0
# 2431                         7.0                   10.0                 9.0
# 2449                         4.0                   10.0                 4.0
# 2461                         5.0                    7.0                 8.0
# 2467                         9.0                    9.0                 8.0
# 3048                        10.0                   10.0                 8.0
# 3049                        10.0                   10.0                10.0
# 3050                        10.0                   10.0                10.0
# 3066                        10.0                   10.0                 8.0
# 3074                        10.0                   10.0                10.0
#
#      requires_license instant_bookable cancellation_policy  \
# 468                 f                f              strict
# 488                 f                f              strict
# 556                 f                f            flexible
# 572                 f                f              strict
# 575                 f                f              strict
# 579                 f                f              strict
# 589                 f                f              strict
# 599                 f                f              strict
# 611                 f                f              strict
# 624                 f                f              strict
# 1301                f                f              strict
# 1339                f                f              strict
# 1418                f                f              strict
# 1449                f                f              strict
# 1463                f                f              strict
# 1797                f                f              strict
# 1799                f                f              strict
# 1815                f                f              strict
# 1822                f                f              strict
# 2070                f                f              strict
# 2108                f                f              strict
# 2114                f                f              strict
# 2117                f                f              strict
# 2249                f                f              strict
# 2270                f                f              strict
# 2291                f                f              strict
# 2301                f                f              strict
# 2317                f                f              strict
# 2319                f                f              strict
# 2328                f                f              strict
# 2335                f                f              strict
# 2337                f                f              strict
# 2355                f                f              strict
# 2360                f                f              strict
# 2361                f                f              strict
# 2364                f                f              strict
# 2368                f                f              strict
# 2396                f                f              strict
# 2403                f                f              strict
# 2414                f                f              strict
# 2418                f                f              strict
# 2421                f                f              strict
# 2431                f                f              strict
# 2449                f                f              strict
# 2461                f                f              strict
# 2467                f                f              strict
# 3048                f                f              strict
# 3049                f                f              strict
# 3050                f                f              strict
# 3066                f                f              strict
# 3074                f                f              strict
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 468                              f                                f
# 488                              f                                f
# 556                              f                                f
# 572                              f                                f
# 575                              f                                f
# 579                              f                                f
# 589                              f                                f
# 599                              f                                f
# 611                              f                                f
# 624                              f                                f
# 1301                             f                                f
# 1339                             f                                f
# 1418                             f                                f
# 1449                             f                                f
# 1463                             f                                f
# 1797                             f                                f
# 1799                             f                                f
# 1815                             f                                f
# 1822                             f                                f
# 2070                             f                                f
# 2108                             f                                f
# 2114                             f                                f
# 2117                             f                                f
# 2249                             f                                f
# 2270                             f                                f
# 2291                             f                                f
# 2301                             f                                f
# 2317                             f                                f
# 2319                             f                                f
# 2328                             f                                f
# 2335                             f                                f
# 2337                             f                                f
# 2355                             f                                f
# 2360                             f                                f
# 2361                             f                                f
# 2364                             f                                f
# 2368                             f                                f
# 2396                             f                                f
# 2403                             f                                f
# 2414                             f                                f
# 2418                             f                                f
# 2421                             f                                f
# 2431                             f                                f
# 2449                             f                                f
# 2461                             f                                f
# 2467                             f                                f
# 3048                             f                                f
# 3049                             f                                f
# 3050                             f                                f
# 3066                             f                                f
# 3074                             f                                f
#
#      calculated_host_listings_count  reviews_per_month
# 468                             136               0.22
# 488                             136               0.16
# 556                             136               0.54
# 572                             136               0.27
# 575                             136               0.77
# 579                             136               0.58
# 589                             136               0.14
# 599                             136               0.13
# 611                             136               0.20
# 624                             136               0.25
# 1301                            136               0.19
# 1339                            136               0.29
# 1418                            136               0.66
# 1449                            136               0.24
# 1463                            136               0.36
# 1797                            136               0.63
# 1799                            136               0.31
# 1815                            136               0.19
# 1822                            136               0.35
# 2070                            136               1.27
# 2108                            136               0.30
# 2114                            136               1.00
# 2117                            136               0.60
# 2249                            136               0.20
# 2270                            136               0.18
# 2291                            136               0.08
# 2301                            136               0.31
# 2317                            136               0.23
# 2319                            136               0.11
# 2328                            136               0.18
# 2335                            136               1.00
# 2337                            136               0.22
# 2355                            136               0.21
# 2360                            136               0.29
# 2361                            136               0.13
# 2364                            136               0.25
# 2368                            136               0.26
# 2396                            136               0.31
# 2403                            136               1.00
# 2414                            136               0.64
# 2418                            136               0.09
# 2421                            136               0.15
# 2431                            136               0.17
# 2449                            136               0.43
# 2461                            136               0.13
# 2467                            136               0.14
# 3048                            136               0.38
# 3049                            136               0.20
# 3050                            136               0.30
# 3066                            136               0.40
# 3074                            136               0.21
#
# [51 rows x 90 columns]

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  2.763000e+03  2.763000e+03  2.763000e+03          2763.000000
# mean   7.629217e+06  2.016091e+13  2.289688e+07            42.852696
# std    4.382781e+06  8.360888e-01  2.191961e+07           139.838053
# min    3.353000e+03  2.016091e+13  4.240000e+03             1.000000
# 25%    4.080424e+06  2.016091e+13  5.235073e+06             1.000000
# 50%    7.708436e+06  2.016091e+13  1.670821e+07             2.000000
# 75%    1.175731e+07  2.016091e+13  3.295588e+07             7.000000
# max    1.484378e+07  2.016091e+13  9.287818e+07           749.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                2763.000000  2763.000000  2763.000000   2763.000000
# mean                   42.852696    42.339191   -71.083699      3.062251
# std                   139.838053     0.024983     0.031696      1.823621
# min                     1.000000    42.235942   -71.171469      1.000000
# 25%                     1.000000    42.326383   -71.104995      2.000000
# 50%                     2.000000    42.344835   -71.077165      2.000000
# 75%                     7.000000    42.355030   -71.061670      4.000000
# max                   749.000000    42.389982   -71.000100     16.000000
#
#          bathrooms     bedrooms  ...  number_of_reviews  review_scores_rating  \
# count  2751.000000  2756.000000  ...        2763.000000           2763.000000
# mean      1.215558     1.251089  ...          24.682591             91.922910
# std       0.500063     0.767830  ...          38.771199              9.531391
# min       0.000000     0.000000  ...           1.000000             20.000000
# 25%       1.000000     1.000000  ...           3.000000             89.000000
# 50%       1.000000     1.000000  ...          10.000000             94.000000
# 75%       1.000000     1.000000  ...          29.000000             98.000000
# max       6.000000     5.000000  ...         404.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             2759.000000                2762.000000
# mean                 9.431678                   9.258146
# std                  0.931846                   1.169289
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            2762.000000                  2762.000000
# mean                9.645909                     9.647357
# std                 0.763078                     0.734745
# min                 2.000000                     4.000000
# 25%                 9.000000                     9.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             2761.000000          2763.000000
# mean                 9.413618             9.169381
# std                  0.903626             1.009500
# min                  2.000000             2.000000
# 25%                  9.000000             9.000000
# 50%                 10.000000             9.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                     2763.000000        2763.000000
# mean                        10.105682           2.007097
# std                         23.669636           2.131826
# min                          1.000000           0.020000
# 25%                          1.000000           0.500000
# 50%                          2.000000           1.240000
# 75%                          5.000000           2.780000
# max                        136.000000          19.150000
#
# [8 rows x 28 columns]

# %%
list(listings.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'instant_bookable',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %%
selected_columns = ['id','accommodates','bathrooms',
                     'bedrooms','beds','price','number_of_reviews',
                     'review_scores_rating','review_scores_accuracy', 'review_scores_cleanliness',
                     'review_scores_checkin', 'review_scores_communication',
                     'review_scores_location', 'review_scores_value','neighbourhood']

# %%
listings=listings[selected_columns]
listings.head()
# Out:
#          id  accommodates  bathrooms  bedrooms  beds   price  \
# 1   3075044             2        1.0       1.0   1.0  $65.00
# 2      6976             2        1.0       1.0   1.0  $65.00
# 3   1436513             4        1.0       1.0   2.0  $75.00
# 4   7651065             2        1.5       1.0   2.0  $79.00
# 5  12386020             2        1.0       1.0   1.0  $75.00
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 1                 36                  94.0                    10.0
# 2                 41                  98.0                    10.0
# 3                  1                 100.0                    10.0
# 4                 29                  99.0                    10.0
# 5                  8                 100.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
# 5                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
# 5                         10.0                     9.0                 10.0
#
#   neighbourhood
# 1    Roslindale
# 2    Roslindale
# 3           NaN
# 4    Roslindale
# 5    Roslindale

# %%
wrangle_prices = lambda x : (x.replace('.00','').replace('$','').replace(',',''))
listings['price']=listings['price'].apply(wrangle_prices)
listings['price'] = pd.to_numeric(listings['price'])

listings.head()
# Out:
#          id  accommodates  bathrooms  bedrooms  beds  price  \
# 1   3075044             2        1.0       1.0   1.0     65
# 2      6976             2        1.0       1.0   1.0     65
# 3   1436513             4        1.0       1.0   2.0     75
# 4   7651065             2        1.5       1.0   2.0     79
# 5  12386020             2        1.0       1.0   1.0     75
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 1                 36                  94.0                    10.0
# 2                 41                  98.0                    10.0
# 3                  1                 100.0                    10.0
# 4                 29                  99.0                    10.0
# 5                  8                 100.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
# 5                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
# 5                         10.0                     9.0                 10.0
#
#   neighbourhood
# 1    Roslindale
# 2    Roslindale
# 3           NaN
# 4    Roslindale
# 5    Roslindale

# %% [markdown]
# ### data exploration and Cleaning for reviews Datasets

# %%
pd.reset_option('all')
# Out:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_config\config.py:622: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 6 columns):
# listing_id       68275 non-null int64
# id               68275 non-null int64
# date             68275 non-null object
# reviewer_id      68275 non-null int64
# reviewer_name    68275 non-null object
# comments         68222 non-null object
# dtypes: int64(3), object(3)
# memory usage: 3.1+ MB

# %%
reviews.describe()
# Out:
#          listing_id            id   reviewer_id
# count  6.827500e+04  6.827500e+04  6.827500e+04
# mean   4.759910e+06  5.246516e+07  2.802389e+07
# std    3.788990e+06  2.790991e+07  2.234097e+07
# min    3.353000e+03  1.021000e+03  1.430000e+02
# 25%    1.458081e+06  3.010420e+07  9.001346e+06
# 50%    4.080000e+06  5.223121e+07  2.305179e+07
# 75%    7.377034e+06  7.663248e+07  4.213454e+07
# max    1.484378e+07  9.999045e+07  9.335034e+07

# %%
listings.rename(columns={"id": "listing_id"},inplace=True)

# %%
listings['listing_id']=listings['listing_id'].astype(str)

# %%
reviews[['listing_id','id']]=reviews[['listing_id','id']].astype(str)

# %%
df_clean=pd.merge(listings,reviews,on='listing_id',how='inner' )

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68198 entries, 0 to 68197
# Data columns (total 20 columns):
# listing_id                     68198 non-null object
# accommodates                   68198 non-null int64
# bathrooms                      67433 non-null float64
# bedrooms                       68012 non-null float64
# beds                           68085 non-null float64
# price                          68198 non-null int64
# number_of_reviews              68198 non-null int64
# review_scores_rating           68198 non-null float64
# review_scores_accuracy         68194 non-null float64
# review_scores_cleanliness      68197 non-null float64
# review_scores_checkin          68197 non-null float64
# review_scores_communication    68197 non-null float64
# review_scores_location         68195 non-null float64
# review_scores_value            68198 non-null float64
# neighbourhood                  60702 non-null object
# id                             68198 non-null object
# date                           68198 non-null object
# reviewer_id                    68198 non-null int64
# reviewer_name                  68198 non-null object
# comments                       68145 non-null object
# dtypes: float64(10), int64(4), object(6)
# memory usage: 10.9+ MB

# %% [markdown]
# # data explantions

# %% [markdown]
# ### what is Boston's  revenue forcast during year  ?

# %%
calendar
# Out:
#         listing_id       date available  price
# 365        3075044 2017-08-22         t     65
# 366        3075044 2017-08-21         t     65
# 367        3075044 2017-08-20         t     65
# 368        3075044 2017-08-19         t     75
# 369        3075044 2017-08-18         t     75
# ...            ...        ...       ...    ...
# 1308875   14504422 2016-09-20         t     62
# 1308876   14504422 2016-09-19         t     62
# 1308877   14504422 2016-09-18         t     62
# 1308878   14504422 2016-09-17         t     62
# 1308879   14504422 2016-09-16         t     62
#
# [643037 rows x 4 columns]

# %%
calendar['month'] = pd.to_datetime(calendar['date']).dt.to_period('M')

calendar.groupby('month')['price'].sum()
# Out:
# month
# 2016-09     6165579
# 2016-10    10817676
# 2016-11    11949813
# 2016-12    11748139
# 2017-01    11549466
# 2017-02    10280396
# 2017-03    10032940
# 2017-04    10135248
# 2017-05    10382979
# 2017-06    10363503
# 2017-07    11129255
# 2017-08    11297226
# 2017-09     1751341
# Freq: M, Name: price, dtype: int64

# %%
calendar['month'] = pd.to_datetime(calendar['date']).dt.to_period('M')
calendar.groupby('month')['price'].sum().plot.line();
plt.ylabel('Revenue in 10mil$)');
plt.xlabel('Months');
plt.title('Relation between Months in Revenue ');

# %% [markdown]
# > Findings 1
# #### we can follow Relation between Months in Revenue to :
# >Boston Travel Seasons
#
# - High (May-October): Late spring through early fall sees hardly any slow times in Boston. May, June, and September are busy with college graduations and move-ins. Surprisingly, October is the most expensive month to visit, when the city fills up with visitors for fall foliage, the regatta, and Halloween in Salem. June through August are peak travel months for families, with July seeing the highest volume of tourists. Expect high rates at hotels all summer, along with queues and crowds at popular attractions. Make your reservations early.
#
# - Low (November-February): Fewer visitors head to Boston during these cold months, so there are plenty of deals to be had on flights and hotels. November is the exception to this; though there are less travelers, hotel rates are still high since this is a popular month for conventions. Overall, if cold and snow don’t bother you, there are plenty of fantastic deals to be had along with less crowded attractions.
#
# - Shoulder (March-April): Weather can be iffy during these months, sometimes snowy, often rainy, and still fairly chilly most of the time. Dress in layers, and enjoy the seasonal attractions that are just beginning to re-open now, but do plan for a few rainy day museum visits.

# %% [markdown]
# ### Are listing's price effected it's frequency use ?

# %%
df_clean[df_clean['price']<200].shape[0]/df_clean.shape[0]
# Out:
# 0.7903164315669081

# %%
# price distribution
df_clean['price'].hist(bins=40)
plt.title('distribution of airbnb price')
plt.xlabel('price/night in $')
plt.ylabel('frequency')
mean = df_clean['price'].mean()
plt.axvline(200, color='r', linestyle='dashed', linewidth=2)
print(f'house average rental price is {mean}')
plt.axvline(50, color='r', linestyle='dashed', linewidth=2)
# Out:
# house average rental price is 147.20012317076748

# %% [markdown]
# >Finding 2
# - it show here that 61% of uses was for listings under avarge cost of night in boston and there dramtic lack of uses after the listing price go over 200dollar per night as 80% of uses was under 200dollar per night and highest demand is between 50~105 dollar per night

# %% [markdown]
# ##  How much users are satisfaed with lisitngs's price and what they paying  ?

# %%
rating_per=df_clean['review_scores_value'].value_counts()/df_clean.shape[0]

# %%
rating_per
# Out:
# 9.0     0.567993
# 10.0    0.338646
# 8.0     0.086483
# 7.0     0.004458
# 6.0     0.001848
# 4.0     0.000308
# 2.0     0.000117
# 5.0     0.000073
# 3.0     0.000073
# Name: review_scores_value, dtype: float64

# %%
rating_per.plot.bar();
plt.ylabel('Users  %');
plt.xlabel('Rating score');
plt.title('Relation between value satisfaction and listing price ');

# %% [markdown]
# - diging for more insights

# %%
df_clean.groupby('review_scores_value')['price'].mean().plot.bar();
plt.ylabel('price/night in $)');
plt.xlabel('value satisfaction');
plt.title('Relation between Value satisfaction in listing price/night ');

# %% [markdown]
# >Finding 3
# - it doesn't show an oblivious Rating trend but show imp. quality it's not about the who much they pay it about having great experience in the exchange
